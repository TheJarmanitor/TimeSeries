# %%
library(readr)
library(rugarch)
# Out:
# Warning message:
# "package 'rugarch' was built under R version 4.0.3"
# Loading required package: parallel
#
#
# Attaching package: 'rugarch'
#
#
# The following object is masked from 'package:stats':
#
#     sigma

# %%
df=read_csv("Datos históricos ECO.csv")
# Out:
# Parsed with column specification:
# cols(
#   Fecha = col_character(),
#   Último = col_number(),
#   Apertura = col_number(),
#   Máximo = col_number(),
#   Mínimo = col_number(),
#   Vol. = col_character(),
#   `% var.` = col_character()
# )

# %%
df=ts(df$Apertura)

# %%
df
# Out:
# A Time Series:
#   [1]    2.0200    1.8700    1.7950    1.8510    1.8710    1.9200    1.9330
#   [8]    1.9500    2.0600    2.0300    2.1300    2.1900    2.1850    2.1800
#  [15]    2.1900    2.1500    2.2000    2.1900    2.0850    2.1100    2.1050
#  [22]    2.1450    2.1900    2.3500    1.9450    2.0050    1.9900    2.0500
#  [29]    2.0000    1.8600    1.9400    2.3800    2.2700    1.8000    1.4800
#  [36]    1.8550    2.9500    3.1400    3.3750    3.3250    3.2000    3.1600
#  [43]    3.2850    3.3750    3.4000    3.3900    3.3400    3.3000    3.3300
#  [50]    3.2900    3.2500    3.1400    3.1150    3.1600    3.0950    3.0500
#  [57]    2.9100    2.9900    2.9550    2.9600    2.9950    2.9700    2.8400
#  [64]    2.7150    2.6300    2.7650    2.8350    2.9000    2.9750    3.0100
#  [71]    3.0650    3.0150    2.9200    3.0000    2.7750    2.8700    2.7850
#  [78]    2.9600    3.0700    3.0500    2.9000    3.0050    3.0400    3.2600
# ...
